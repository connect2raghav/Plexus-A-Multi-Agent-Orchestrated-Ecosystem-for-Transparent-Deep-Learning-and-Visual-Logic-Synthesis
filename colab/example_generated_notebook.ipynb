# %% [markdown]
# # Example: Generated Neural Network Notebook
#
# This is an example of what the generated notebook looks like when you use the "Get Colab Notebook" feature.
#
# ## What you get:
# - Complete setup and installation instructions
# - Sample data generation for testing
# - Your custom neural network architecture
# - Full training pipeline with callbacks
# - Visualization and evaluation tools
# - Model saving and export functionality
#
# ---

# %%
# This cell installs all required dependencies
# !pip install tensorflow pandas numpy matplotlib seaborn scikit-learn

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"GPU Available: {tf.config.list_physical_devices('GPU')}")

# %% [markdown]
# ## How to use this with your designs:
#
# 1. **Design your network** in the visual editor
# 2. **Click "Get Colab Notebook"** to download your custom notebook
# 3. **Upload to Google Colab** and start training immediately
# 4. **All your layer configurations** are automatically included
# 5. **Complete training environment** with GPU support
#
# The generated notebook will contain your exact architecture with proper connections and parameters!
